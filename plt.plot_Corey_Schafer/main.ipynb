# %% [markdown]
# [Corey_Schafer](https://www.youtube.com/watch?v=UO98lJQ3QGI&list=PL-osiE80TeTvipOqomVEeZ1HRrcEvtZB_&index=2&t=0s)
# [codebasics](https://www.youtube.com/watch?v=oETDriX9n1w)

# %%
# %matplotlib inline
# https://versusall.tistory.com/entry/Jupyter-Notebook-4-%EC%99%B8%EB%B6%80%EC%B0%BD%EC%97%90%EC%84%9C-%EA%B7%B8%EB%9E%98%ED%94%84-%EA%B7%B8%EB%A6%AC%EA%B8%B0-matplotlib-inline-qt-tk%C2%B6
# %matplotlib qt
# %matplotlib qt5
# %matplotlib tk
import matplotlib.pyplot as plt

#print(plt.style.available)
#plt.style.use('seaborn')
plt.xkcd()

days = [10,11,12,13,14,15,16]
max_t = [50,51,52,48,47,49,46]
min_t = [43,42,40,44,33,35,37]
avg_t = [45,48,48,46,40,42,41]

plt.plot(days, max_t, linestyle='--', color='k', marker='o', label='max')
plt.plot(days, avg_t, color='#2714e7', label='average')
plt.plot(days, min_t, linestyle='--', color='k', marker='o', label='min')

plt.legend(loc='lower left', fontsize='large', shadow=True)
plt.grid(True)
#plt.tight_layout()

plt.title('Seoul')
plt.xlabel('Date')
plt.ylabel('Temperature')

plt.savefig('plot.png')

plt.show()

# %%
print(plt.style.available)
# Out:
# ['seaborn-dark', 'seaborn-darkgrid', 'seaborn-ticks', 'fivethirtyeight', 'seaborn-whitegrid', 'classic', '_classic_test', 'fast', 'seaborn-talk', 'seaborn-dark-palette', 'seaborn-bright', 'seaborn-pastel', 'grayscale', 'seaborn-notebook', 'ggplot', 'seaborn-colorblind', 'seaborn-muted', 'seaborn', 'Solarize_Light2', 'seaborn-paper', 'bmh', 'tableau-colorblind10', 'seaborn-white', 'dark_background', 'seaborn-poster', 'seaborn-deep']

# %%
# %matplotlib inline
#%matplotlib qt
import matplotlib.pyplot as plt
import pandas as pd

#print(plt.style.available)
plt.style.use('seaborn-dark')
#plt.xkcd()

n = 1000

SPY = pd.read_csv('dow30/SPY.csv').set_index('Date')
SPY.index = pd.to_datetime(SPY.index)
DATE = SPY.index[:n]
SPY = list((SPY['Adj Close'].loc[DATE] / SPY['Adj Close'].loc[DATE[0]]) * 100)

AAPL = pd.read_csv('dow30/AAPL.csv').set_index('Date')
AAPL.index = pd.to_datetime(AAPL.index)
AAPL = list((AAPL['Adj Close'].loc[DATE] / AAPL['Adj Close'].loc[DATE[0]]) * 100)

WMT = pd.read_csv('dow30/WMT.csv').set_index('Date')
WMT.index = pd.to_datetime(WMT.index)
WMT = list((WMT['Adj Close'].loc[DATE] / WMT['Adj Close'].loc[DATE[0]]) * 100)

plt.plot(DATE, SPY, color='#444444', linestyle='--', label='SPY')
plt.plot(DATE, AAPL, label='AAPL')
plt.plot(DATE, WMT, label='WMT')

plt.xlabel('DATE')
plt.ylabel('STOCK PRICE')
plt.title('STOCK PRICE (STARTING AT 100)')

plt.legend()
plt.grid(True)
plt.tight_layout()

#plt.savefig('plot.png')

plt.show()
# Out:
# /Users/sungchullee/anaconda3/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
