# %% [markdown]
# [Erik Marsja](https://youtu.be/TexdD7t0IKU).

# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv')
df.to_csv('data/mtcars.csv')
df = pd.read_csv('data/mtcars.csv', index_col=0)
print(df.head())
print(df.shape)
print(df.vs)
# Out:
#         Unnamed: 0.1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# (32, 12)
# 0     0
# 1     0
# 2     1
# 3     1
# 4     0
# 5     1
# 6     0
# 7     1
# 8     1
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    0
# 15    0
# 16    0
# 17    1
# 18    1
# 19    1
# 20    1
# 21    0
# 22    0
# 23    0
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    0
# 30    0
# 31    1
# Name: vs, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.plot(df.wt, df.mpg, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(df.wt, df.mpg)
plt.show()

# %%
import pandas as pd

df.plot(x='wt', y='mpg', kind='scatter')
#df.plot.scatter(x='wt', y='mpg')

# %%
import seaborn as sns

# "Styling"
# sns.set_style('white')
# sns.set_style('ticks')

sns.regplot(x='wt', y='mpg', data=df)
#sns.regplot(x='wt', y='mpg', data=df, lowess=True)
#sns.regplot(x='wt', y='mpg', data=df, ci=None)
#sns.regplot(x='wt', y='mpg', color='g', data=df)

# %% [markdown]
# This function combines regplot() and FacetGrid. It is intended as a convenient interface to fit regression models across conditional subsets of a dataset.
#
# https://seaborn.pydata.org/generated/seaborn.lmplot.html

# %%
import seaborn as sns

# # "Styling"
# sns.set_style('white')
# sns.set_style('ticks')

#sns.lmplot(x='wt', y='mpg', data=df) 
#sns.lmplot(x='wt', y='mpg', data=df, hue='vs')
#sns.lmplot(x='wt', y='mpg', data=df, hue='vs', palette="Set2")
#sns.lmplot(x='wt', y='mpg', data=df, hue='vs',palette="Set1", markers='+')
sns.lmplot(x='wt', y='mpg', data=df, hue='vs',palette="Set1", markers=['+', 'o'])
